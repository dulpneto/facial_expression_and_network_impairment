# %%
import os
from pathlib import Path
import pickle
import numpy as np
import pandas as pd
from glob import glob

# %%
data_file = r"drive/MyDrive/facial-1018-all-data-column.pkl"
with open(data_file, "rb") as f:
  data = pickle.load(f)

# %%
def split_and_reshape(dd, seq_length):
    # given dict, return (-1,10,323), (-1,5)

    # for x, split in seq size of seq_length
    x = dd['features']    # (-1,328)

    # extract the data part (0-frame, 1-face_id, 2-timestamp, 3-confidence, 4-success, gaze_0_x...)

    # filter to data with high confidence and success
    condition = (x[:,3]> 0.9) & (x[:,4]> 0.99)
    x = x[condition]
    x = x[:, 5:]  # get only feature information (from gaze_0_x...)
    x = x[30*30:, :] # discard the first 12s
    dim = x.shape[1]

    # take multiple of seq_length
    seq_num = int(x.shape[0]/seq_length)
    x = x[:seq_num*seq_length]
    # assert x.shape[1]== 323, "Expected shape of (-1,323) for feature"
    x = x.reshape((-1,seq_length,dim))

    # for y, replicate of each sequence
    # y = np.array([value for key, value in dd.items() if key != 'features'])  # (5,)
    y = np.array([dd['delay'], dd['jitter'], dd['packet_loss_rate']])
    y = np.tile(y, (seq_num,1))

    return x, y

def convert_to_seq_feature(data, seq_length=10):
    x_list, y_list = [], []
    for d in data:
        x,y = split_and_reshape(d, seq_length)   # return (-1,seq_length,323), (-1,5)
        x_list.append(x)
        y_list.append(y)

    # append along the first dimension
    X = np.concatenate(x_list, axis=0)
    Y = np.concatenate(y_list, axis=0)
    return X, Y

# %%
X, Y = convert_to_seq_feature(data, seq_length=30)
X.shape, Y.shape
# Out:
# ((25428, 30, 323), (25428, 3))

# %%
for i in range(0,3):
  print(i,set(Y[:,i]))
# Out:
# 0 {1000, 0, 500}
# 1 {0, 500}
# 2 {0, 30, 15}

# %%
# encode categories
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Discretize each feature into bins
delay_bins = pd.cut(Y[:, 0], bins=3, labels=False)
jitter_bins = pd.cut(Y[:, 1], bins=3, labels=False)
package_loss_bins = pd.cut(Y[:, 2], bins=3, labels=False)

# Initialize LabelEncoders for each feature
delay_encoder = LabelEncoder()
jitter_encoder = LabelEncoder()
package_loss_encoder = LabelEncoder()

# Fit and transform the binned values
delay_encoded = delay_encoder.fit_transform(delay_bins)
jitter_encoded = jitter_encoder.fit_transform(jitter_bins)
package_loss_encoded = package_loss_encoder.fit_transform(package_loss_bins)

# Combine the encoded values
Y_encoded = np.stack((delay_encoded, jitter_encoded, package_loss_encoded), axis=1)

# %%
for i in range(0,3):
  print(i,set(Y_encoded[:,i]))
# Out:
# 0 {0, 1, 2}
# 1 {0, 1}
# 2 {0, 1, 2}

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoders for each feature
delay_encoder = LabelEncoder()
jitter_encoder = LabelEncoder()
package_loss_encoder = LabelEncoder()

# Fit and transform the binned values
delay_encoded = delay_encoder.fit_transform(delay_bins)
jitter_encoded = jitter_encoder.fit_transform(jitter_bins)
package_loss_encoded = package_loss_encoder.fit_transform(package_loss_bins)

# Combine the encoded values
Y_encoded = np.stack((delay_encoded, jitter_encoded, package_loss_encoded), axis=1)

# %%
for i in range(0,3):
  print(i,set(Y_encoded[:,i]))
# Out:
# 0 {0, 1, 2}
# 1 {0, 1}
# 2 {0, 1, 2}

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, GRU, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping

# %%
# prepare dataset
X_train, X_val, Y_train, Y_val = train_test_split(X, Y_encoded, test_size=0.1, random_state=42)
X_train.shape, Y_train.shape, X_val.shape, Y_val.shape
# Out:
# ((22885, 30, 323), (22885, 3), (2543, 30, 323), (2543, 3))

# %%
# Reshape the data to 2D for normalization
X_train_reshaped = X_train.reshape(-1, X_train.shape[-1])
X_val_reshaped = X_val.reshape(-1, X_val.shape[-1])

# Standardize the data
scaler = StandardScaler()
X_train_reshaped = scaler.fit_transform(X_train_reshaped)
X_val_reshaped = scaler.transform(X_val_reshaped)

# Reshape back to the original shape
X_train = X_train_reshaped.reshape(X_train.shape)
X_val = X_val_reshaped.reshape(X_val.shape)
X_train.shape, Y_train.shape, X_val.shape, Y_val.shape
# Out:
# ((22885, 30, 323), (22885, 3), (2543, 30, 323), (2543, 3))

# %%
def create_model():
  # Define the input layer
  input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))  # Replace input_dim with your input dimension

  gru_1 = GRU(128, return_sequences=True)(input_layer)
  batch_1 = BatchNormalization()(gru_1)
  gru_2 = GRU(64, return_sequences=False)(batch_1)
  batch_2 = BatchNormalization()(gru_2)
  dense_1 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(batch_2)
  drop_1 = tf.keras.layers.Dropout(0.2)(dense_1)
  dense_2 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(drop_1)
  drop_2 = tf.keras.layers.Dropout(0.2)(dense_2)
  hidden_layer = drop_2

  # Define separate output layers for each feature
  output_delay = Dense(3, activation='softmax', name='delay_output')(hidden_layer)  # 3 categories for delay
  output_jitter = Dense(2, activation='softmax', name='jitter_output')(hidden_layer)        # 2 categories for jitter
  output_packet_loss = Dense(3, activation='softmax', name='packet_loss_output')(hidden_layer)  # 3 categories for packet loss

  # Define the model with multiple outputs
  model = Model(inputs=input_layer, outputs=[output_delay, output_jitter, output_packet_loss])

  # Compile the model
  model.compile(optimizer='adam',
                  loss={'delay_output': 'SparseCategoricalCrossentropy',
                        'jitter_output': 'SparseCategoricalCrossentropy',
                        'packet_loss_output': 'SparseCategoricalCrossentropy'},
                  metrics=['accuracy'])

  return model

model = create_model()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30, 323)]            0         []
#
#  gru (GRU)                   (None, 30, 128)              173952    ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 30, 128)              512       ['gru[0][0]']
#  Normalization)
#
#  gru_1 (GRU)                 (None, 64)                   37248     ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 64)                   256       ['gru_1[0][0]']
#  chNormalization)
#
#  dense (Dense)               (None, 32)                   2080      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 32)                   0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 32)                   1056      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 32)                   0         ['dense_1[0][0]']
#
#  delay_output (Dense)        (None, 3)                    99        ['dropout_1[0][0]']
#
#  jitter_output (Dense)       (None, 2)                    66        ['dropout_1[0][0]']
#
#  packet_loss_output (Dense)  (None, 3)                    99        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 215368 (841.28 KB)
# Trainable params: 214984 (839.78 KB)
# Non-trainable params: 384 (1.50 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import TensorBoard
import datetime
import matplotlib.pyplot as plt

# %%
current_timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
log_dir = f'drive/MyDrive/tensorflow_logs_1026_{current_timestamp}'
print(log_dir)
tensorboard_callback = TensorBoard(log_dir=log_dir)
# Out:
# drive/MyDrive/tensorflow_logs_1026_20240520_031539

# %%
early_stopping = EarlyStopping(monitor='loss', patience=20, restore_best_weights=True)

# %%
history_list = []
def fit():
  history = model.fit(X_train, [Y_train[:,0], Y_train[:,1], Y_train[:,2]],
          epochs = 500,
          batch_size=32,
          validation_data = (X_val, [Y_val[:,0], Y_val[:,1], Y_val[:,2]]),
          callbacks=[tensorboard_callback, early_stopping]
  )
  history_list.append(history)
  return history

# %%
fit()
# Out:
# Epoch 1/500
# 716/716 [==============================] - 16s 12ms/step - loss: 3.2134 - delay_output_loss: 1.0564 - jitter_output_loss: 0.6668 - packet_loss_output_loss: 1.0934 - delay_output_accuracy: 0.4144 - jitter_output_accuracy: 0.6114 - packet_loss_output_accuracy: 0.3768 - val_loss: 2.9334 - val_delay_output_loss: 1.0452 - val_jitter_output_loss: 0.6525 - val_packet_loss_output_loss: 1.0725 - val_delay_output_accuracy: 0.4298 - val_jitter_output_accuracy: 0.6304 - val_packet_loss_output_accuracy: 0.4133
# Epoch 2/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.8093 - delay_output_loss: 1.0201 - jitter_output_loss: 0.6400 - packet_loss_output_loss: 1.0600 - delay_output_accuracy: 0.4402 - jitter_output_accuracy: 0.6426 - packet_loss_output_accuracy: 0.4260 - val_loss: 2.7382 - val_delay_output_loss: 1.0142 - val_jitter_output_loss: 0.6325 - val_packet_loss_output_loss: 1.0409 - val_delay_output_accuracy: 0.4542 - val_jitter_output_accuracy: 0.6481 - val_packet_loss_output_accuracy: 0.4392
# Epoch 3/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.6859 - delay_output_loss: 0.9935 - jitter_output_loss: 0.6227 - packet_loss_output_loss: 1.0283 - delay_output_accuracy: 0.4671 - jitter_output_accuracy: 0.6588 - packet_loss_output_accuracy: 0.4601 - val_loss: 2.6480 - val_delay_output_loss: 0.9745 - val_jitter_output_loss: 0.6215 - val_packet_loss_output_loss: 1.0158 - val_delay_output_accuracy: 0.4849 - val_jitter_output_accuracy: 0.6500 - val_packet_loss_output_accuracy: 0.4782
# Epoch 4/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.6025 - delay_output_loss: 0.9673 - jitter_output_loss: 0.6013 - packet_loss_output_loss: 0.9968 - delay_output_accuracy: 0.4889 - jitter_output_accuracy: 0.6769 - packet_loss_output_accuracy: 0.4877 - val_loss: 2.5339 - val_delay_output_loss: 0.9367 - val_jitter_output_loss: 0.5866 - val_packet_loss_output_loss: 0.9729 - val_delay_output_accuracy: 0.5112 - val_jitter_output_accuracy: 0.6823 - val_packet_loss_output_accuracy: 0.5049
# Epoch 5/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.5254 - delay_output_loss: 0.9429 - jitter_output_loss: 0.5776 - packet_loss_output_loss: 0.9658 - delay_output_accuracy: 0.5071 - jitter_output_accuracy: 0.6954 - packet_loss_output_accuracy: 0.5160 - val_loss: 2.4863 - val_delay_output_loss: 0.9335 - val_jitter_output_loss: 0.5661 - val_packet_loss_output_loss: 0.9463 - val_delay_output_accuracy: 0.5053 - val_jitter_output_accuracy: 0.6890 - val_packet_loss_output_accuracy: 0.5203
# Epoch 6/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.4521 - delay_output_loss: 0.9130 - jitter_output_loss: 0.5610 - packet_loss_output_loss: 0.9359 - delay_output_accuracy: 0.5376 - jitter_output_accuracy: 0.7088 - packet_loss_output_accuracy: 0.5393 - val_loss: 2.3884 - val_delay_output_loss: 0.8830 - val_jitter_output_loss: 0.5538 - val_packet_loss_output_loss: 0.9077 - val_delay_output_accuracy: 0.5600 - val_jitter_output_accuracy: 0.7106 - val_packet_loss_output_accuracy: 0.5741
# Epoch 7/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.3832 - delay_output_loss: 0.8924 - jitter_output_loss: 0.5415 - packet_loss_output_loss: 0.9037 - delay_output_accuracy: 0.5563 - jitter_output_accuracy: 0.7251 - packet_loss_output_accuracy: 0.5664 - val_loss: 2.3377 - val_delay_output_loss: 0.8612 - val_jitter_output_loss: 0.5286 - val_packet_loss_output_loss: 0.9026 - val_delay_output_accuracy: 0.5635 - val_jitter_output_accuracy: 0.7330 - val_packet_loss_output_accuracy: 0.5686
# Epoch 8/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.3072 - delay_output_loss: 0.8625 - jitter_output_loss: 0.5188 - packet_loss_output_loss: 0.8764 - delay_output_accuracy: 0.5764 - jitter_output_accuracy: 0.7386 - packet_loss_output_accuracy: 0.5821 - val_loss: 2.3211 - val_delay_output_loss: 0.8588 - val_jitter_output_loss: 0.5357 - val_packet_loss_output_loss: 0.8771 - val_delay_output_accuracy: 0.5678 - val_jitter_output_accuracy: 0.7365 - val_packet_loss_output_accuracy: 0.5851
# Epoch 9/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.2458 - delay_output_loss: 0.8379 - jitter_output_loss: 0.5062 - packet_loss_output_loss: 0.8495 - delay_output_accuracy: 0.5900 - jitter_output_accuracy: 0.7472 - packet_loss_output_accuracy: 0.6042 - val_loss: 2.2581 - val_delay_output_loss: 0.8485 - val_jitter_output_loss: 0.5069 - val_packet_loss_output_loss: 0.8509 - val_delay_output_accuracy: 0.5954 - val_jitter_output_accuracy: 0.7432 - val_packet_loss_output_accuracy: 0.6052
# Epoch 10/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.1748 - delay_output_loss: 0.8158 - jitter_output_loss: 0.4830 - packet_loss_output_loss: 0.8221 - delay_output_accuracy: 0.6078 - jitter_output_accuracy: 0.7654 - packet_loss_output_accuracy: 0.6241 - val_loss: 2.1377 - val_delay_output_loss: 0.8076 - val_jitter_output_loss: 0.4838 - val_packet_loss_output_loss: 0.7922 - val_delay_output_accuracy: 0.6103 - val_jitter_output_accuracy: 0.7562 - val_packet_loss_output_accuracy: 0.6504
# Epoch 11/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.1186 - delay_output_loss: 0.7935 - jitter_output_loss: 0.4727 - packet_loss_output_loss: 0.7961 - delay_output_accuracy: 0.6231 - jitter_output_accuracy: 0.7725 - packet_loss_output_accuracy: 0.6406 - val_loss: 2.1329 - val_delay_output_loss: 0.7981 - val_jitter_output_loss: 0.4941 - val_packet_loss_output_loss: 0.7831 - val_delay_output_accuracy: 0.6225 - val_jitter_output_accuracy: 0.7593 - val_packet_loss_output_accuracy: 0.6492
# Epoch 12/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.0695 - delay_output_loss: 0.7760 - jitter_output_loss: 0.4581 - packet_loss_output_loss: 0.7770 - delay_output_accuracy: 0.6328 - jitter_output_accuracy: 0.7806 - packet_loss_output_accuracy: 0.6491 - val_loss: 2.1434 - val_delay_output_loss: 0.8031 - val_jitter_output_loss: 0.5032 - val_packet_loss_output_loss: 0.7791 - val_delay_output_accuracy: 0.6217 - val_jitter_output_accuracy: 0.7625 - val_packet_loss_output_accuracy: 0.6579
# Epoch 13/500
# 716/716 [==============================] - 7s 10ms/step - loss: 2.0171 - delay_output_loss: 0.7526 - jitter_output_loss: 0.4478 - packet_loss_output_loss: 0.7570 - delay_output_accuracy: 0.6546 - jitter_output_accuracy: 0.7865 - packet_loss_output_accuracy: 0.6631 - val_loss: 2.0672 - val_delay_output_loss: 0.7695 - val_jitter_output_loss: 0.4646 - val_packet_loss_output_loss: 0.7746 - val_delay_output_accuracy: 0.6319 - val_jitter_output_accuracy: 0.7774 - val_packet_loss_output_accuracy: 0.6575
# Epoch 14/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.9595 - delay_output_loss: 0.7337 - jitter_output_loss: 0.4343 - packet_loss_output_loss: 0.7309 - delay_output_accuracy: 0.6668 - jitter_output_accuracy: 0.7935 - packet_loss_output_accuracy: 0.6767 - val_loss: 2.0208 - val_delay_output_loss: 0.7485 - val_jitter_output_loss: 0.4568 - val_packet_loss_output_loss: 0.7558 - val_delay_output_accuracy: 0.6587 - val_jitter_output_accuracy: 0.7825 - val_packet_loss_output_accuracy: 0.6697
# Epoch 15/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.9053 - delay_output_loss: 0.7119 - jitter_output_loss: 0.4209 - packet_loss_output_loss: 0.7099 - delay_output_accuracy: 0.6746 - jitter_output_accuracy: 0.8028 - packet_loss_output_accuracy: 0.6878 - val_loss: 1.9963 - val_delay_output_loss: 0.7358 - val_jitter_output_loss: 0.4603 - val_packet_loss_output_loss: 0.7373 - val_delay_output_accuracy: 0.6697 - val_jitter_output_accuracy: 0.7849 - val_packet_loss_output_accuracy: 0.6748
# Epoch 16/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.8810 - delay_output_loss: 0.7051 - jitter_output_loss: 0.4152 - packet_loss_output_loss: 0.6978 - delay_output_accuracy: 0.6828 - jitter_output_accuracy: 0.8055 - packet_loss_output_accuracy: 0.6980 - val_loss: 1.9732 - val_delay_output_loss: 0.7249 - val_jitter_output_loss: 0.4555 - val_packet_loss_output_loss: 0.7299 - val_delay_output_accuracy: 0.6709 - val_jitter_output_accuracy: 0.7865 - val_packet_loss_output_accuracy: 0.6705
# Epoch 17/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.8391 - delay_output_loss: 0.6810 - jitter_output_loss: 0.4050 - packet_loss_output_loss: 0.6903 - delay_output_accuracy: 0.6974 - jitter_output_accuracy: 0.8120 - packet_loss_output_accuracy: 0.7021 - val_loss: 1.9424 - val_delay_output_loss: 0.7101 - val_jitter_output_loss: 0.4579 - val_packet_loss_output_loss: 0.7113 - val_delay_output_accuracy: 0.6764 - val_jitter_output_accuracy: 0.7912 - val_packet_loss_output_accuracy: 0.6976
# Epoch 18/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.7980 - delay_output_loss: 0.6688 - jitter_output_loss: 0.3970 - packet_loss_output_loss: 0.6691 - delay_output_accuracy: 0.7036 - jitter_output_accuracy: 0.8172 - packet_loss_output_accuracy: 0.7126 - val_loss: 1.9569 - val_delay_output_loss: 0.7171 - val_jitter_output_loss: 0.4576 - val_packet_loss_output_loss: 0.7208 - val_delay_output_accuracy: 0.6669 - val_jitter_output_accuracy: 0.7770 - val_packet_loss_output_accuracy: 0.6858
# Epoch 19/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.7562 - delay_output_loss: 0.6552 - jitter_output_loss: 0.3861 - packet_loss_output_loss: 0.6510 - delay_output_accuracy: 0.7079 - jitter_output_accuracy: 0.8217 - packet_loss_output_accuracy: 0.7251 - val_loss: 1.9541 - val_delay_output_loss: 0.7165 - val_jitter_output_loss: 0.4558 - val_packet_loss_output_loss: 0.7189 - val_delay_output_accuracy: 0.6752 - val_jitter_output_accuracy: 0.7884 - val_packet_loss_output_accuracy: 0.6870
# Epoch 20/500
# 716/716 [==============================] - 8s 10ms/step - loss: 1.7300 - delay_output_loss: 0.6411 - jitter_output_loss: 0.3815 - packet_loss_output_loss: 0.6434 - delay_output_accuracy: 0.7167 - jitter_output_accuracy: 0.8230 - packet_loss_output_accuracy: 0.7295 - val_loss: 1.8821 - val_delay_output_loss: 0.6970 - val_jitter_output_loss: 0.4346 - val_packet_loss_output_loss: 0.6860 - val_delay_output_accuracy: 0.6909 - val_jitter_output_accuracy: 0.8022 - val_packet_loss_output_accuracy: 0.7047
# Epoch 21/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.6887 - delay_output_loss: 0.6319 - jitter_output_loss: 0.3673 - packet_loss_output_loss: 0.6251 - delay_output_accuracy: 0.7250 - jitter_output_accuracy: 0.8331 - packet_loss_output_accuracy: 0.7356 - val_loss: 1.9412 - val_delay_output_loss: 0.7235 - val_jitter_output_loss: 0.4566 - val_packet_loss_output_loss: 0.6985 - val_delay_output_accuracy: 0.6716 - val_jitter_output_accuracy: 0.7932 - val_packet_loss_output_accuracy: 0.7051
# Epoch 22/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.6871 - delay_output_loss: 0.6244 - jitter_output_loss: 0.3711 - packet_loss_output_loss: 0.6283 - delay_output_accuracy: 0.7305 - jitter_output_accuracy: 0.8318 - packet_loss_output_accuracy: 0.7349 - val_loss: 1.9147 - val_delay_output_loss: 0.6971 - val_jitter_output_loss: 0.4584 - val_packet_loss_output_loss: 0.6949 - val_delay_output_accuracy: 0.6925 - val_jitter_output_accuracy: 0.8144 - val_packet_loss_output_accuracy: 0.7023
# Epoch 23/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.6367 - delay_output_loss: 0.6058 - jitter_output_loss: 0.3605 - packet_loss_output_loss: 0.6065 - delay_output_accuracy: 0.7395 - jitter_output_accuracy: 0.8372 - packet_loss_output_accuracy: 0.7439 - val_loss: 1.8473 - val_delay_output_loss: 0.6708 - val_jitter_output_loss: 0.4335 - val_packet_loss_output_loss: 0.6785 - val_delay_output_accuracy: 0.7035 - val_jitter_output_accuracy: 0.8101 - val_packet_loss_output_accuracy: 0.7122
# Epoch 24/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.6114 - delay_output_loss: 0.5952 - jitter_output_loss: 0.3544 - packet_loss_output_loss: 0.5970 - delay_output_accuracy: 0.7415 - jitter_output_accuracy: 0.8400 - packet_loss_output_accuracy: 0.7497 - val_loss: 1.8457 - val_delay_output_loss: 0.6850 - val_jitter_output_loss: 0.4384 - val_packet_loss_output_loss: 0.6594 - val_delay_output_accuracy: 0.7007 - val_jitter_output_accuracy: 0.8065 - val_packet_loss_output_accuracy: 0.7295
# Epoch 25/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.6019 - delay_output_loss: 0.5888 - jitter_output_loss: 0.3537 - packet_loss_output_loss: 0.5957 - delay_output_accuracy: 0.7469 - jitter_output_accuracy: 0.8396 - packet_loss_output_accuracy: 0.7528 - val_loss: 1.9002 - val_delay_output_loss: 0.6957 - val_jitter_output_loss: 0.4602 - val_packet_loss_output_loss: 0.6810 - val_delay_output_accuracy: 0.6968 - val_jitter_output_accuracy: 0.8014 - val_packet_loss_output_accuracy: 0.7161
# Epoch 26/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.5610 - delay_output_loss: 0.5727 - jitter_output_loss: 0.3464 - packet_loss_output_loss: 0.5783 - delay_output_accuracy: 0.7577 - jitter_output_accuracy: 0.8420 - packet_loss_output_accuracy: 0.7621 - val_loss: 1.8471 - val_delay_output_loss: 0.6789 - val_jitter_output_loss: 0.4421 - val_packet_loss_output_loss: 0.6619 - val_delay_output_accuracy: 0.7125 - val_jitter_output_accuracy: 0.8030 - val_packet_loss_output_accuracy: 0.7259
# Epoch 27/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.5310 - delay_output_loss: 0.5638 - jitter_output_loss: 0.3347 - packet_loss_output_loss: 0.5681 - delay_output_accuracy: 0.7598 - jitter_output_accuracy: 0.8508 - packet_loss_output_accuracy: 0.7641 - val_loss: 1.8733 - val_delay_output_loss: 0.6864 - val_jitter_output_loss: 0.4625 - val_packet_loss_output_loss: 0.6603 - val_delay_output_accuracy: 0.7129 - val_jitter_output_accuracy: 0.8116 - val_packet_loss_output_accuracy: 0.7251
# Epoch 28/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.5173 - delay_output_loss: 0.5548 - jitter_output_loss: 0.3310 - packet_loss_output_loss: 0.5681 - delay_output_accuracy: 0.7679 - jitter_output_accuracy: 0.8527 - packet_loss_output_accuracy: 0.7631 - val_loss: 1.8830 - val_delay_output_loss: 0.6813 - val_jitter_output_loss: 0.4623 - val_packet_loss_output_loss: 0.6769 - val_delay_output_accuracy: 0.7216 - val_jitter_output_accuracy: 0.8042 - val_packet_loss_output_accuracy: 0.7180
# Epoch 29/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.4923 - delay_output_loss: 0.5523 - jitter_output_loss: 0.3248 - packet_loss_output_loss: 0.5517 - delay_output_accuracy: 0.7681 - jitter_output_accuracy: 0.8563 - packet_loss_output_accuracy: 0.7738 - val_loss: 1.9335 - val_delay_output_loss: 0.7163 - val_jitter_output_loss: 0.4651 - val_packet_loss_output_loss: 0.6902 - val_delay_output_accuracy: 0.7035 - val_jitter_output_accuracy: 0.8140 - val_packet_loss_output_accuracy: 0.7141
# Epoch 30/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.4841 - delay_output_loss: 0.5428 - jitter_output_loss: 0.3298 - packet_loss_output_loss: 0.5494 - delay_output_accuracy: 0.7719 - jitter_output_accuracy: 0.8569 - packet_loss_output_accuracy: 0.7739 - val_loss: 1.8719 - val_delay_output_loss: 0.7006 - val_jitter_output_loss: 0.4359 - val_packet_loss_output_loss: 0.6715 - val_delay_output_accuracy: 0.7094 - val_jitter_output_accuracy: 0.8077 - val_packet_loss_output_accuracy: 0.7279
# Epoch 31/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.4563 - delay_output_loss: 0.5425 - jitter_output_loss: 0.3147 - packet_loss_output_loss: 0.5356 - delay_output_accuracy: 0.7711 - jitter_output_accuracy: 0.8619 - packet_loss_output_accuracy: 0.7798 - val_loss: 1.8332 - val_delay_output_loss: 0.6608 - val_jitter_output_loss: 0.4459 - val_packet_loss_output_loss: 0.6633 - val_delay_output_accuracy: 0.7208 - val_jitter_output_accuracy: 0.8191 - val_packet_loss_output_accuracy: 0.7385
# Epoch 32/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.4534 - delay_output_loss: 0.5290 - jitter_output_loss: 0.3182 - packet_loss_output_loss: 0.5435 - delay_output_accuracy: 0.7791 - jitter_output_accuracy: 0.8617 - packet_loss_output_accuracy: 0.7795 - val_loss: 1.8786 - val_delay_output_loss: 0.6876 - val_jitter_output_loss: 0.4480 - val_packet_loss_output_loss: 0.6809 - val_delay_output_accuracy: 0.7043 - val_jitter_output_accuracy: 0.8152 - val_packet_loss_output_accuracy: 0.7251
# Epoch 33/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.4311 - delay_output_loss: 0.5210 - jitter_output_loss: 0.3114 - packet_loss_output_loss: 0.5359 - delay_output_accuracy: 0.7830 - jitter_output_accuracy: 0.8656 - packet_loss_output_accuracy: 0.7868 - val_loss: 1.8498 - val_delay_output_loss: 0.6624 - val_jitter_output_loss: 0.4635 - val_packet_loss_output_loss: 0.6609 - val_delay_output_accuracy: 0.7224 - val_jitter_output_accuracy: 0.8120 - val_packet_loss_output_accuracy: 0.7271
# Epoch 34/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.4302 - delay_output_loss: 0.5262 - jitter_output_loss: 0.3176 - packet_loss_output_loss: 0.5245 - delay_output_accuracy: 0.7834 - jitter_output_accuracy: 0.8617 - packet_loss_output_accuracy: 0.7881 - val_loss: 1.8037 - val_delay_output_loss: 0.6524 - val_jitter_output_loss: 0.4471 - val_packet_loss_output_loss: 0.6425 - val_delay_output_accuracy: 0.7208 - val_jitter_output_accuracy: 0.8171 - val_packet_loss_output_accuracy: 0.7369
# Epoch 35/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.4141 - delay_output_loss: 0.5153 - jitter_output_loss: 0.3118 - packet_loss_output_loss: 0.5250 - delay_output_accuracy: 0.7851 - jitter_output_accuracy: 0.8624 - packet_loss_output_accuracy: 0.7875 - val_loss: 1.8270 - val_delay_output_loss: 0.6749 - val_jitter_output_loss: 0.4359 - val_packet_loss_output_loss: 0.6554 - val_delay_output_accuracy: 0.7122 - val_jitter_output_accuracy: 0.8148 - val_packet_loss_output_accuracy: 0.7413
# Epoch 36/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.3799 - delay_output_loss: 0.5020 - jitter_output_loss: 0.2997 - packet_loss_output_loss: 0.5165 - delay_output_accuracy: 0.7949 - jitter_output_accuracy: 0.8687 - packet_loss_output_accuracy: 0.7934 - val_loss: 1.8387 - val_delay_output_loss: 0.6995 - val_jitter_output_loss: 0.4422 - val_packet_loss_output_loss: 0.6354 - val_delay_output_accuracy: 0.7220 - val_jitter_output_accuracy: 0.8101 - val_packet_loss_output_accuracy: 0.7468
# Epoch 37/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.3789 - delay_output_loss: 0.5027 - jitter_output_loss: 0.3008 - packet_loss_output_loss: 0.5146 - delay_output_accuracy: 0.7949 - jitter_output_accuracy: 0.8688 - packet_loss_output_accuracy: 0.7951 - val_loss: 1.8367 - val_delay_output_loss: 0.6738 - val_jitter_output_loss: 0.4427 - val_packet_loss_output_loss: 0.6600 - val_delay_output_accuracy: 0.7200 - val_jitter_output_accuracy: 0.8120 - val_packet_loss_output_accuracy: 0.7385
# Epoch 38/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.3634 - delay_output_loss: 0.4951 - jitter_output_loss: 0.2999 - packet_loss_output_loss: 0.5077 - delay_output_accuracy: 0.7956 - jitter_output_accuracy: 0.8718 - packet_loss_output_accuracy: 0.7966 - val_loss: 1.7878 - val_delay_output_loss: 0.6632 - val_jitter_output_loss: 0.4203 - val_packet_loss_output_loss: 0.6443 - val_delay_output_accuracy: 0.7216 - val_jitter_output_accuracy: 0.8254 - val_packet_loss_output_accuracy: 0.7519
# Epoch 39/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.3868 - delay_output_loss: 0.5032 - jitter_output_loss: 0.3034 - packet_loss_output_loss: 0.5195 - delay_output_accuracy: 0.7937 - jitter_output_accuracy: 0.8683 - packet_loss_output_accuracy: 0.7913 - val_loss: 1.8466 - val_delay_output_loss: 0.6745 - val_jitter_output_loss: 0.4587 - val_packet_loss_output_loss: 0.6531 - val_delay_output_accuracy: 0.7232 - val_jitter_output_accuracy: 0.8128 - val_packet_loss_output_accuracy: 0.7428
# Epoch 40/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.3227 - delay_output_loss: 0.4817 - jitter_output_loss: 0.2864 - packet_loss_output_loss: 0.4936 - delay_output_accuracy: 0.8025 - jitter_output_accuracy: 0.8757 - packet_loss_output_accuracy: 0.8028 - val_loss: 1.8014 - val_delay_output_loss: 0.6627 - val_jitter_output_loss: 0.4444 - val_packet_loss_output_loss: 0.6338 - val_delay_output_accuracy: 0.7322 - val_jitter_output_accuracy: 0.8148 - val_packet_loss_output_accuracy: 0.7436
# Epoch 41/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.3133 - delay_output_loss: 0.4779 - jitter_output_loss: 0.2879 - packet_loss_output_loss: 0.4864 - delay_output_accuracy: 0.8055 - jitter_output_accuracy: 0.8765 - packet_loss_output_accuracy: 0.8081 - val_loss: 1.8274 - val_delay_output_loss: 0.6809 - val_jitter_output_loss: 0.4343 - val_packet_loss_output_loss: 0.6537 - val_delay_output_accuracy: 0.7212 - val_jitter_output_accuracy: 0.8148 - val_packet_loss_output_accuracy: 0.7310
# Epoch 42/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.2930 - delay_output_loss: 0.4667 - jitter_output_loss: 0.2848 - packet_loss_output_loss: 0.4799 - delay_output_accuracy: 0.8062 - jitter_output_accuracy: 0.8770 - packet_loss_output_accuracy: 0.8064 - val_loss: 1.8312 - val_delay_output_loss: 0.6455 - val_jitter_output_loss: 0.4643 - val_packet_loss_output_loss: 0.6598 - val_delay_output_accuracy: 0.7306 - val_jitter_output_accuracy: 0.8101 - val_packet_loss_output_accuracy: 0.7377
# Epoch 43/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.3142 - delay_output_loss: 0.4783 - jitter_output_loss: 0.2898 - packet_loss_output_loss: 0.4856 - delay_output_accuracy: 0.8066 - jitter_output_accuracy: 0.8735 - packet_loss_output_accuracy: 0.8051 - val_loss: 1.7737 - val_delay_output_loss: 0.6572 - val_jitter_output_loss: 0.4316 - val_packet_loss_output_loss: 0.6249 - val_delay_output_accuracy: 0.7428 - val_jitter_output_accuracy: 0.8246 - val_packet_loss_output_accuracy: 0.7538
# Epoch 44/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.2903 - delay_output_loss: 0.4718 - jitter_output_loss: 0.2820 - packet_loss_output_loss: 0.4764 - delay_output_accuracy: 0.8091 - jitter_output_accuracy: 0.8809 - packet_loss_output_accuracy: 0.8108 - val_loss: 1.8605 - val_delay_output_loss: 0.6920 - val_jitter_output_loss: 0.4483 - val_packet_loss_output_loss: 0.6596 - val_delay_output_accuracy: 0.7338 - val_jitter_output_accuracy: 0.8187 - val_packet_loss_output_accuracy: 0.7487
# Epoch 45/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.2631 - delay_output_loss: 0.4603 - jitter_output_loss: 0.2746 - packet_loss_output_loss: 0.4686 - delay_output_accuracy: 0.8152 - jitter_output_accuracy: 0.8860 - packet_loss_output_accuracy: 0.8162 - val_loss: 1.8247 - val_delay_output_loss: 0.6665 - val_jitter_output_loss: 0.4524 - val_packet_loss_output_loss: 0.6475 - val_delay_output_accuracy: 0.7428 - val_jitter_output_accuracy: 0.8230 - val_packet_loss_output_accuracy: 0.7377
# Epoch 46/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.2532 - delay_output_loss: 0.4572 - jitter_output_loss: 0.2727 - packet_loss_output_loss: 0.4636 - delay_output_accuracy: 0.8140 - jitter_output_accuracy: 0.8842 - packet_loss_output_accuracy: 0.8141 - val_loss: 1.8571 - val_delay_output_loss: 0.6789 - val_jitter_output_loss: 0.4539 - val_packet_loss_output_loss: 0.6637 - val_delay_output_accuracy: 0.7310 - val_jitter_output_accuracy: 0.8266 - val_packet_loss_output_accuracy: 0.7428
# Epoch 47/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.2565 - delay_output_loss: 0.4565 - jitter_output_loss: 0.2781 - packet_loss_output_loss: 0.4623 - delay_output_accuracy: 0.8149 - jitter_output_accuracy: 0.8826 - packet_loss_output_accuracy: 0.8158 - val_loss: 1.8394 - val_delay_output_loss: 0.6670 - val_jitter_output_loss: 0.4505 - val_packet_loss_output_loss: 0.6642 - val_delay_output_accuracy: 0.7330 - val_jitter_output_accuracy: 0.8219 - val_packet_loss_output_accuracy: 0.7409
# Epoch 48/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.2291 - delay_output_loss: 0.4449 - jitter_output_loss: 0.2687 - packet_loss_output_loss: 0.4559 - delay_output_accuracy: 0.8236 - jitter_output_accuracy: 0.8850 - packet_loss_output_accuracy: 0.8216 - val_loss: 1.8832 - val_delay_output_loss: 0.6981 - val_jitter_output_loss: 0.4593 - val_packet_loss_output_loss: 0.6659 - val_delay_output_accuracy: 0.7322 - val_jitter_output_accuracy: 0.8223 - val_packet_loss_output_accuracy: 0.7405
# Epoch 49/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.2332 - delay_output_loss: 0.4469 - jitter_output_loss: 0.2658 - packet_loss_output_loss: 0.4608 - delay_output_accuracy: 0.8231 - jitter_output_accuracy: 0.8853 - packet_loss_output_accuracy: 0.8203 - val_loss: 1.8671 - val_delay_output_loss: 0.6824 - val_jitter_output_loss: 0.4475 - val_packet_loss_output_loss: 0.6779 - val_delay_output_accuracy: 0.7302 - val_jitter_output_accuracy: 0.8211 - val_packet_loss_output_accuracy: 0.7416
# Epoch 50/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.2417 - delay_output_loss: 0.4524 - jitter_output_loss: 0.2676 - packet_loss_output_loss: 0.4620 - delay_output_accuracy: 0.8187 - jitter_output_accuracy: 0.8872 - packet_loss_output_accuracy: 0.8151 - val_loss: 1.9067 - val_delay_output_loss: 0.6767 - val_jitter_output_loss: 0.5071 - val_packet_loss_output_loss: 0.6625 - val_delay_output_accuracy: 0.7377 - val_jitter_output_accuracy: 0.8183 - val_packet_loss_output_accuracy: 0.7523
# Epoch 51/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.2084 - delay_output_loss: 0.4342 - jitter_output_loss: 0.2634 - packet_loss_output_loss: 0.4503 - delay_output_accuracy: 0.8270 - jitter_output_accuracy: 0.8902 - packet_loss_output_accuracy: 0.8223 - val_loss: 1.8658 - val_delay_output_loss: 0.6924 - val_jitter_output_loss: 0.4689 - val_packet_loss_output_loss: 0.6446 - val_delay_output_accuracy: 0.7318 - val_jitter_output_accuracy: 0.8183 - val_packet_loss_output_accuracy: 0.7432
# Epoch 52/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1890 - delay_output_loss: 0.4283 - jitter_output_loss: 0.2572 - packet_loss_output_loss: 0.4433 - delay_output_accuracy: 0.8263 - jitter_output_accuracy: 0.8892 - packet_loss_output_accuracy: 0.8252 - val_loss: 1.8611 - val_delay_output_loss: 0.6783 - val_jitter_output_loss: 0.4628 - val_packet_loss_output_loss: 0.6607 - val_delay_output_accuracy: 0.7287 - val_jitter_output_accuracy: 0.8242 - val_packet_loss_output_accuracy: 0.7436
# Epoch 53/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1854 - delay_output_loss: 0.4319 - jitter_output_loss: 0.2537 - packet_loss_output_loss: 0.4396 - delay_output_accuracy: 0.8253 - jitter_output_accuracy: 0.8925 - packet_loss_output_accuracy: 0.8262 - val_loss: 1.8186 - val_delay_output_loss: 0.6619 - val_jitter_output_loss: 0.4532 - val_packet_loss_output_loss: 0.6448 - val_delay_output_accuracy: 0.7346 - val_jitter_output_accuracy: 0.8250 - val_packet_loss_output_accuracy: 0.7538
# Epoch 54/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1995 - delay_output_loss: 0.4346 - jitter_output_loss: 0.2608 - packet_loss_output_loss: 0.4449 - delay_output_accuracy: 0.8256 - jitter_output_accuracy: 0.8915 - packet_loss_output_accuracy: 0.8246 - val_loss: 1.8231 - val_delay_output_loss: 0.6588 - val_jitter_output_loss: 0.4503 - val_packet_loss_output_loss: 0.6545 - val_delay_output_accuracy: 0.7385 - val_jitter_output_accuracy: 0.8329 - val_packet_loss_output_accuracy: 0.7471
# Epoch 55/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1776 - delay_output_loss: 0.4277 - jitter_output_loss: 0.2546 - packet_loss_output_loss: 0.4360 - delay_output_accuracy: 0.8297 - jitter_output_accuracy: 0.8923 - packet_loss_output_accuracy: 0.8288 - val_loss: 1.7841 - val_delay_output_loss: 0.6666 - val_jitter_output_loss: 0.4370 - val_packet_loss_output_loss: 0.6207 - val_delay_output_accuracy: 0.7507 - val_jitter_output_accuracy: 0.8227 - val_packet_loss_output_accuracy: 0.7688
# Epoch 56/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1928 - delay_output_loss: 0.4329 - jitter_output_loss: 0.2573 - packet_loss_output_loss: 0.4435 - delay_output_accuracy: 0.8253 - jitter_output_accuracy: 0.8893 - packet_loss_output_accuracy: 0.8263 - val_loss: 1.8433 - val_delay_output_loss: 0.6989 - val_jitter_output_loss: 0.4529 - val_packet_loss_output_loss: 0.6345 - val_delay_output_accuracy: 0.7283 - val_jitter_output_accuracy: 0.8183 - val_packet_loss_output_accuracy: 0.7550
# Epoch 57/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1772 - delay_output_loss: 0.4273 - jitter_output_loss: 0.2541 - packet_loss_output_loss: 0.4374 - delay_output_accuracy: 0.8271 - jitter_output_accuracy: 0.8953 - packet_loss_output_accuracy: 0.8254 - val_loss: 1.7591 - val_delay_output_loss: 0.6423 - val_jitter_output_loss: 0.4343 - val_packet_loss_output_loss: 0.6239 - val_delay_output_accuracy: 0.7491 - val_jitter_output_accuracy: 0.8344 - val_packet_loss_output_accuracy: 0.7574
# Epoch 58/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1444 - delay_output_loss: 0.4098 - jitter_output_loss: 0.2470 - packet_loss_output_loss: 0.4278 - delay_output_accuracy: 0.8368 - jitter_output_accuracy: 0.8981 - packet_loss_output_accuracy: 0.8297 - val_loss: 1.7868 - val_delay_output_loss: 0.6542 - val_jitter_output_loss: 0.4547 - val_packet_loss_output_loss: 0.6200 - val_delay_output_accuracy: 0.7487 - val_jitter_output_accuracy: 0.8285 - val_packet_loss_output_accuracy: 0.7621
# Epoch 59/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1407 - delay_output_loss: 0.4119 - jitter_output_loss: 0.2451 - packet_loss_output_loss: 0.4255 - delay_output_accuracy: 0.8358 - jitter_output_accuracy: 0.8964 - packet_loss_output_accuracy: 0.8353 - val_loss: 1.8488 - val_delay_output_loss: 0.6526 - val_jitter_output_loss: 0.4805 - val_packet_loss_output_loss: 0.6576 - val_delay_output_accuracy: 0.7479 - val_jitter_output_accuracy: 0.8285 - val_packet_loss_output_accuracy: 0.7456
# Epoch 60/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1355 - delay_output_loss: 0.4083 - jitter_output_loss: 0.2447 - packet_loss_output_loss: 0.4240 - delay_output_accuracy: 0.8380 - jitter_output_accuracy: 0.8976 - packet_loss_output_accuracy: 0.8355 - val_loss: 1.7751 - val_delay_output_loss: 0.6500 - val_jitter_output_loss: 0.4282 - val_packet_loss_output_loss: 0.6382 - val_delay_output_accuracy: 0.7420 - val_jitter_output_accuracy: 0.8313 - val_packet_loss_output_accuracy: 0.7656
# Epoch 61/500
# 716/716 [==============================] - 8s 10ms/step - loss: 1.1395 - delay_output_loss: 0.4115 - jitter_output_loss: 0.2481 - packet_loss_output_loss: 0.4215 - delay_output_accuracy: 0.8389 - jitter_output_accuracy: 0.8960 - packet_loss_output_accuracy: 0.8370 - val_loss: 1.8573 - val_delay_output_loss: 0.6735 - val_jitter_output_loss: 0.4655 - val_packet_loss_output_loss: 0.6587 - val_delay_output_accuracy: 0.7542 - val_jitter_output_accuracy: 0.8337 - val_packet_loss_output_accuracy: 0.7538
# Epoch 62/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1333 - delay_output_loss: 0.4113 - jitter_output_loss: 0.2459 - packet_loss_output_loss: 0.4174 - delay_output_accuracy: 0.8380 - jitter_output_accuracy: 0.8986 - packet_loss_output_accuracy: 0.8379 - val_loss: 1.8256 - val_delay_output_loss: 0.6753 - val_jitter_output_loss: 0.4489 - val_packet_loss_output_loss: 0.6440 - val_delay_output_accuracy: 0.7479 - val_jitter_output_accuracy: 0.8333 - val_packet_loss_output_accuracy: 0.7601
# Epoch 63/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1429 - delay_output_loss: 0.4161 - jitter_output_loss: 0.2481 - packet_loss_output_loss: 0.4207 - delay_output_accuracy: 0.8362 - jitter_output_accuracy: 0.8980 - packet_loss_output_accuracy: 0.8350 - val_loss: 1.8568 - val_delay_output_loss: 0.6896 - val_jitter_output_loss: 0.4582 - val_packet_loss_output_loss: 0.6515 - val_delay_output_accuracy: 0.7409 - val_jitter_output_accuracy: 0.8321 - val_packet_loss_output_accuracy: 0.7574
# Epoch 64/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1270 - delay_output_loss: 0.4059 - jitter_output_loss: 0.2425 - packet_loss_output_loss: 0.4206 - delay_output_accuracy: 0.8401 - jitter_output_accuracy: 0.9002 - packet_loss_output_accuracy: 0.8345 - val_loss: 1.7876 - val_delay_output_loss: 0.6656 - val_jitter_output_loss: 0.4361 - val_packet_loss_output_loss: 0.6289 - val_delay_output_accuracy: 0.7413 - val_jitter_output_accuracy: 0.8250 - val_packet_loss_output_accuracy: 0.7613
# Epoch 65/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1402 - delay_output_loss: 0.4117 - jitter_output_loss: 0.2481 - packet_loss_output_loss: 0.4236 - delay_output_accuracy: 0.8376 - jitter_output_accuracy: 0.8991 - packet_loss_output_accuracy: 0.8358 - val_loss: 1.8769 - val_delay_output_loss: 0.7042 - val_jitter_output_loss: 0.4461 - val_packet_loss_output_loss: 0.6708 - val_delay_output_accuracy: 0.7397 - val_jitter_output_accuracy: 0.8305 - val_packet_loss_output_accuracy: 0.7554
# Epoch 66/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.1300 - delay_output_loss: 0.4095 - jitter_output_loss: 0.2445 - packet_loss_output_loss: 0.4188 - delay_output_accuracy: 0.8367 - jitter_output_accuracy: 0.8991 - packet_loss_output_accuracy: 0.8365 - val_loss: 1.9391 - val_delay_output_loss: 0.6989 - val_jitter_output_loss: 0.4762 - val_packet_loss_output_loss: 0.7059 - val_delay_output_accuracy: 0.7479 - val_jitter_output_accuracy: 0.8313 - val_packet_loss_output_accuracy: 0.7495
# Epoch 67/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0776 - delay_output_loss: 0.3856 - jitter_output_loss: 0.2372 - packet_loss_output_loss: 0.3966 - delay_output_accuracy: 0.8483 - jitter_output_accuracy: 0.9036 - packet_loss_output_accuracy: 0.8474 - val_loss: 1.8636 - val_delay_output_loss: 0.6989 - val_jitter_output_loss: 0.4572 - val_packet_loss_output_loss: 0.6495 - val_delay_output_accuracy: 0.7428 - val_jitter_output_accuracy: 0.8337 - val_packet_loss_output_accuracy: 0.7633
# Epoch 68/500
# 716/716 [==============================] - 8s 11ms/step - loss: 1.0940 - delay_output_loss: 0.3923 - jitter_output_loss: 0.2389 - packet_loss_output_loss: 0.4051 - delay_output_accuracy: 0.8468 - jitter_output_accuracy: 0.9020 - packet_loss_output_accuracy: 0.8424 - val_loss: 1.8281 - val_delay_output_loss: 0.6916 - val_jitter_output_loss: 0.4436 - val_packet_loss_output_loss: 0.6369 - val_delay_output_accuracy: 0.7428 - val_jitter_output_accuracy: 0.8258 - val_packet_loss_output_accuracy: 0.7617
# Epoch 69/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0978 - delay_output_loss: 0.3967 - jitter_output_loss: 0.2334 - packet_loss_output_loss: 0.4104 - delay_output_accuracy: 0.8413 - jitter_output_accuracy: 0.9035 - packet_loss_output_accuracy: 0.8385 - val_loss: 1.7547 - val_delay_output_loss: 0.6522 - val_jitter_output_loss: 0.4182 - val_packet_loss_output_loss: 0.6285 - val_delay_output_accuracy: 0.7574 - val_jitter_output_accuracy: 0.8364 - val_packet_loss_output_accuracy: 0.7617
# Epoch 70/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0717 - delay_output_loss: 0.3857 - jitter_output_loss: 0.2308 - packet_loss_output_loss: 0.3980 - delay_output_accuracy: 0.8468 - jitter_output_accuracy: 0.9047 - packet_loss_output_accuracy: 0.8441 - val_loss: 1.8309 - val_delay_output_loss: 0.6857 - val_jitter_output_loss: 0.4550 - val_packet_loss_output_loss: 0.6335 - val_delay_output_accuracy: 0.7416 - val_jitter_output_accuracy: 0.8274 - val_packet_loss_output_accuracy: 0.7570
# Epoch 71/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0980 - delay_output_loss: 0.3994 - jitter_output_loss: 0.2337 - packet_loss_output_loss: 0.4078 - delay_output_accuracy: 0.8412 - jitter_output_accuracy: 0.9052 - packet_loss_output_accuracy: 0.8392 - val_loss: 1.7955 - val_delay_output_loss: 0.6485 - val_jitter_output_loss: 0.4550 - val_packet_loss_output_loss: 0.6355 - val_delay_output_accuracy: 0.7456 - val_jitter_output_accuracy: 0.8329 - val_packet_loss_output_accuracy: 0.7621
# Epoch 72/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0950 - delay_output_loss: 0.3962 - jitter_output_loss: 0.2343 - packet_loss_output_loss: 0.4079 - delay_output_accuracy: 0.8445 - jitter_output_accuracy: 0.9040 - packet_loss_output_accuracy: 0.8422 - val_loss: 1.7930 - val_delay_output_loss: 0.6666 - val_jitter_output_loss: 0.4404 - val_packet_loss_output_loss: 0.6294 - val_delay_output_accuracy: 0.7487 - val_jitter_output_accuracy: 0.8329 - val_packet_loss_output_accuracy: 0.7566
# Epoch 73/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0702 - delay_output_loss: 0.3823 - jitter_output_loss: 0.2346 - packet_loss_output_loss: 0.3962 - delay_output_accuracy: 0.8508 - jitter_output_accuracy: 0.9036 - packet_loss_output_accuracy: 0.8467 - val_loss: 1.9456 - val_delay_output_loss: 0.7142 - val_jitter_output_loss: 0.5057 - val_packet_loss_output_loss: 0.6693 - val_delay_output_accuracy: 0.7432 - val_jitter_output_accuracy: 0.8234 - val_packet_loss_output_accuracy: 0.7656
# Epoch 74/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0650 - delay_output_loss: 0.3809 - jitter_output_loss: 0.2296 - packet_loss_output_loss: 0.3976 - delay_output_accuracy: 0.8526 - jitter_output_accuracy: 0.9081 - packet_loss_output_accuracy: 0.8441 - val_loss: 1.8579 - val_delay_output_loss: 0.6944 - val_jitter_output_loss: 0.4509 - val_packet_loss_output_loss: 0.6560 - val_delay_output_accuracy: 0.7475 - val_jitter_output_accuracy: 0.8341 - val_packet_loss_output_accuracy: 0.7637
# Epoch 75/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0730 - delay_output_loss: 0.3877 - jitter_output_loss: 0.2321 - packet_loss_output_loss: 0.3960 - delay_output_accuracy: 0.8462 - jitter_output_accuracy: 0.9048 - packet_loss_output_accuracy: 0.8451 - val_loss: 1.9589 - val_delay_output_loss: 0.6929 - val_jitter_output_loss: 0.4997 - val_packet_loss_output_loss: 0.7079 - val_delay_output_accuracy: 0.7550 - val_jitter_output_accuracy: 0.8313 - val_packet_loss_output_accuracy: 0.7582
# Epoch 76/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0497 - delay_output_loss: 0.3797 - jitter_output_loss: 0.2235 - packet_loss_output_loss: 0.3895 - delay_output_accuracy: 0.8511 - jitter_output_accuracy: 0.9111 - packet_loss_output_accuracy: 0.8494 - val_loss: 1.8065 - val_delay_output_loss: 0.6691 - val_jitter_output_loss: 0.4430 - val_packet_loss_output_loss: 0.6385 - val_delay_output_accuracy: 0.7444 - val_jitter_output_accuracy: 0.8364 - val_packet_loss_output_accuracy: 0.7637
# Epoch 77/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0266 - delay_output_loss: 0.3711 - jitter_output_loss: 0.2185 - packet_loss_output_loss: 0.3795 - delay_output_accuracy: 0.8558 - jitter_output_accuracy: 0.9114 - packet_loss_output_accuracy: 0.8531 - val_loss: 1.8212 - val_delay_output_loss: 0.6780 - val_jitter_output_loss: 0.4486 - val_packet_loss_output_loss: 0.6394 - val_delay_output_accuracy: 0.7538 - val_jitter_output_accuracy: 0.8305 - val_packet_loss_output_accuracy: 0.7625
# Epoch 78/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0506 - delay_output_loss: 0.3708 - jitter_output_loss: 0.2274 - packet_loss_output_loss: 0.3962 - delay_output_accuracy: 0.8554 - jitter_output_accuracy: 0.9067 - packet_loss_output_accuracy: 0.8481 - val_loss: 1.8272 - val_delay_output_loss: 0.6913 - val_jitter_output_loss: 0.4715 - val_packet_loss_output_loss: 0.6079 - val_delay_output_accuracy: 0.7589 - val_jitter_output_accuracy: 0.8368 - val_packet_loss_output_accuracy: 0.7790
# Epoch 79/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0364 - delay_output_loss: 0.3710 - jitter_output_loss: 0.2231 - packet_loss_output_loss: 0.3856 - delay_output_accuracy: 0.8570 - jitter_output_accuracy: 0.9089 - packet_loss_output_accuracy: 0.8519 - val_loss: 1.8804 - val_delay_output_loss: 0.7070 - val_jitter_output_loss: 0.4679 - val_packet_loss_output_loss: 0.6490 - val_delay_output_accuracy: 0.7452 - val_jitter_output_accuracy: 0.8297 - val_packet_loss_output_accuracy: 0.7684
# Epoch 80/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0458 - delay_output_loss: 0.3795 - jitter_output_loss: 0.2267 - packet_loss_output_loss: 0.3834 - delay_output_accuracy: 0.8513 - jitter_output_accuracy: 0.9068 - packet_loss_output_accuracy: 0.8520 - val_loss: 1.8122 - val_delay_output_loss: 0.6845 - val_jitter_output_loss: 0.4365 - val_packet_loss_output_loss: 0.6366 - val_delay_output_accuracy: 0.7471 - val_jitter_output_accuracy: 0.8403 - val_packet_loss_output_accuracy: 0.7668
# Epoch 81/500
# 716/716 [==============================] - 8s 11ms/step - loss: 1.0266 - delay_output_loss: 0.3643 - jitter_output_loss: 0.2223 - packet_loss_output_loss: 0.3842 - delay_output_accuracy: 0.8572 - jitter_output_accuracy: 0.9095 - packet_loss_output_accuracy: 0.8524 - val_loss: 1.8848 - val_delay_output_loss: 0.7017 - val_jitter_output_loss: 0.4778 - val_packet_loss_output_loss: 0.6502 - val_delay_output_accuracy: 0.7503 - val_jitter_output_accuracy: 0.8337 - val_packet_loss_output_accuracy: 0.7711
# Epoch 82/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0052 - delay_output_loss: 0.3625 - jitter_output_loss: 0.2187 - packet_loss_output_loss: 0.3676 - delay_output_accuracy: 0.8572 - jitter_output_accuracy: 0.9109 - packet_loss_output_accuracy: 0.8586 - val_loss: 1.8733 - val_delay_output_loss: 0.6931 - val_jitter_output_loss: 0.4761 - val_packet_loss_output_loss: 0.6470 - val_delay_output_accuracy: 0.7593 - val_jitter_output_accuracy: 0.8376 - val_packet_loss_output_accuracy: 0.7743
# Epoch 83/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0153 - delay_output_loss: 0.3612 - jitter_output_loss: 0.2188 - packet_loss_output_loss: 0.3792 - delay_output_accuracy: 0.8585 - jitter_output_accuracy: 0.9109 - packet_loss_output_accuracy: 0.8554 - val_loss: 1.8465 - val_delay_output_loss: 0.6838 - val_jitter_output_loss: 0.4719 - val_packet_loss_output_loss: 0.6359 - val_delay_output_accuracy: 0.7593 - val_jitter_output_accuracy: 0.8348 - val_packet_loss_output_accuracy: 0.7676
# Epoch 84/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0155 - delay_output_loss: 0.3629 - jitter_output_loss: 0.2170 - packet_loss_output_loss: 0.3798 - delay_output_accuracy: 0.8587 - jitter_output_accuracy: 0.9130 - packet_loss_output_accuracy: 0.8543 - val_loss: 1.8476 - val_delay_output_loss: 0.6692 - val_jitter_output_loss: 0.4770 - val_packet_loss_output_loss: 0.6460 - val_delay_output_accuracy: 0.7578 - val_jitter_output_accuracy: 0.8317 - val_packet_loss_output_accuracy: 0.7723
# Epoch 85/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9944 - delay_output_loss: 0.3526 - jitter_output_loss: 0.2150 - packet_loss_output_loss: 0.3707 - delay_output_accuracy: 0.8658 - jitter_output_accuracy: 0.9130 - packet_loss_output_accuracy: 0.8565 - val_loss: 1.8755 - val_delay_output_loss: 0.6943 - val_jitter_output_loss: 0.4892 - val_packet_loss_output_loss: 0.6361 - val_delay_output_accuracy: 0.7479 - val_jitter_output_accuracy: 0.8297 - val_packet_loss_output_accuracy: 0.7762
# Epoch 86/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9990 - delay_output_loss: 0.3559 - jitter_output_loss: 0.2190 - packet_loss_output_loss: 0.3686 - delay_output_accuracy: 0.8614 - jitter_output_accuracy: 0.9121 - packet_loss_output_accuracy: 0.8596 - val_loss: 1.8878 - val_delay_output_loss: 0.7092 - val_jitter_output_loss: 0.4758 - val_packet_loss_output_loss: 0.6469 - val_delay_output_accuracy: 0.7609 - val_jitter_output_accuracy: 0.8486 - val_packet_loss_output_accuracy: 0.7798
# Epoch 87/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0082 - delay_output_loss: 0.3642 - jitter_output_loss: 0.2174 - packet_loss_output_loss: 0.3713 - delay_output_accuracy: 0.8601 - jitter_output_accuracy: 0.9100 - packet_loss_output_accuracy: 0.8573 - val_loss: 1.8897 - val_delay_output_loss: 0.7141 - val_jitter_output_loss: 0.4780 - val_packet_loss_output_loss: 0.6429 - val_delay_output_accuracy: 0.7507 - val_jitter_output_accuracy: 0.8380 - val_packet_loss_output_accuracy: 0.7703
# Epoch 88/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9938 - delay_output_loss: 0.3555 - jitter_output_loss: 0.2154 - packet_loss_output_loss: 0.3674 - delay_output_accuracy: 0.8620 - jitter_output_accuracy: 0.9148 - packet_loss_output_accuracy: 0.8581 - val_loss: 1.8163 - val_delay_output_loss: 0.6682 - val_jitter_output_loss: 0.4465 - val_packet_loss_output_loss: 0.6468 - val_delay_output_accuracy: 0.7641 - val_jitter_output_accuracy: 0.8392 - val_packet_loss_output_accuracy: 0.7684
# Epoch 89/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9900 - delay_output_loss: 0.3572 - jitter_output_loss: 0.2155 - packet_loss_output_loss: 0.3624 - delay_output_accuracy: 0.8609 - jitter_output_accuracy: 0.9129 - packet_loss_output_accuracy: 0.8630 - val_loss: 1.8334 - val_delay_output_loss: 0.6584 - val_jitter_output_loss: 0.4557 - val_packet_loss_output_loss: 0.6651 - val_delay_output_accuracy: 0.7554 - val_jitter_output_accuracy: 0.8356 - val_packet_loss_output_accuracy: 0.7656
# Epoch 90/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9949 - delay_output_loss: 0.3540 - jitter_output_loss: 0.2130 - packet_loss_output_loss: 0.3729 - delay_output_accuracy: 0.8626 - jitter_output_accuracy: 0.9129 - packet_loss_output_accuracy: 0.8584 - val_loss: 1.9465 - val_delay_output_loss: 0.7356 - val_jitter_output_loss: 0.4975 - val_packet_loss_output_loss: 0.6588 - val_delay_output_accuracy: 0.7428 - val_jitter_output_accuracy: 0.8282 - val_packet_loss_output_accuracy: 0.7676
# Epoch 91/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0046 - delay_output_loss: 0.3622 - jitter_output_loss: 0.2160 - packet_loss_output_loss: 0.3713 - delay_output_accuracy: 0.8612 - jitter_output_accuracy: 0.9117 - packet_loss_output_accuracy: 0.8564 - val_loss: 1.8604 - val_delay_output_loss: 0.6877 - val_jitter_output_loss: 0.4664 - val_packet_loss_output_loss: 0.6518 - val_delay_output_accuracy: 0.7637 - val_jitter_output_accuracy: 0.8344 - val_packet_loss_output_accuracy: 0.7719
# Epoch 92/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9696 - delay_output_loss: 0.3417 - jitter_output_loss: 0.2105 - packet_loss_output_loss: 0.3622 - delay_output_accuracy: 0.8686 - jitter_output_accuracy: 0.9147 - packet_loss_output_accuracy: 0.8625 - val_loss: 1.7820 - val_delay_output_loss: 0.6599 - val_jitter_output_loss: 0.4313 - val_packet_loss_output_loss: 0.6354 - val_delay_output_accuracy: 0.7621 - val_jitter_output_accuracy: 0.8462 - val_packet_loss_output_accuracy: 0.7700
# Epoch 93/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9725 - delay_output_loss: 0.3520 - jitter_output_loss: 0.2039 - packet_loss_output_loss: 0.3605 - delay_output_accuracy: 0.8645 - jitter_output_accuracy: 0.9179 - packet_loss_output_accuracy: 0.8645 - val_loss: 1.8711 - val_delay_output_loss: 0.6636 - val_jitter_output_loss: 0.5128 - val_packet_loss_output_loss: 0.6391 - val_delay_output_accuracy: 0.7617 - val_jitter_output_accuracy: 0.8364 - val_packet_loss_output_accuracy: 0.7692
# Epoch 94/500
# ...
# Epoch 137/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9036 - delay_output_loss: 0.3223 - jitter_output_loss: 0.1904 - packet_loss_output_loss: 0.3389 - delay_output_accuracy: 0.8795 - jitter_output_accuracy: 0.9253 - packet_loss_output_accuracy: 0.8751 - val_loss: 1.9545 - val_delay_output_loss: 0.7133 - val_jitter_output_loss: 0.4795 - val_packet_loss_output_loss: 0.7106 - val_delay_output_accuracy: 0.7527 - val_jitter_output_accuracy: 0.8411 - val_packet_loss_output_accuracy: 0.7609
# Epoch 138/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9241 - delay_output_loss: 0.3260 - jitter_output_loss: 0.1964 - packet_loss_output_loss: 0.3497 - delay_output_accuracy: 0.8759 - jitter_output_accuracy: 0.9231 - packet_loss_output_accuracy: 0.8703 - val_loss: 2.0634 - val_delay_output_loss: 0.7924 - val_jitter_output_loss: 0.5121 - val_packet_loss_output_loss: 0.7077 - val_delay_output_accuracy: 0.7420 - val_jitter_output_accuracy: 0.8242 - val_packet_loss_output_accuracy: 0.7586
# Epoch 139/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9220 - delay_output_loss: 0.3273 - jitter_output_loss: 0.1956 - packet_loss_output_loss: 0.3469 - delay_output_accuracy: 0.8771 - jitter_output_accuracy: 0.9243 - packet_loss_output_accuracy: 0.8722 - val_loss: 1.9928 - val_delay_output_loss: 0.7479 - val_jitter_output_loss: 0.4970 - val_packet_loss_output_loss: 0.6992 - val_delay_output_accuracy: 0.7157 - val_jitter_output_accuracy: 0.8120 - val_packet_loss_output_accuracy: 0.7357
# Epoch 140/500
# 716/716 [==============================] - 7s 10ms/step - loss: 1.0740 - delay_output_loss: 0.3851 - jitter_output_loss: 0.2366 - packet_loss_output_loss: 0.4038 - delay_output_accuracy: 0.8568 - jitter_output_accuracy: 0.9064 - packet_loss_output_accuracy: 0.8473 - val_loss: 1.9510 - val_delay_output_loss: 0.7325 - val_jitter_output_loss: 0.5125 - val_packet_loss_output_loss: 0.6573 - val_delay_output_accuracy: 0.7578 - val_jitter_output_accuracy: 0.8266 - val_packet_loss_output_accuracy: 0.7672
# Epoch 141/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9623 - delay_output_loss: 0.3469 - jitter_output_loss: 0.2107 - packet_loss_output_loss: 0.3548 - delay_output_accuracy: 0.8689 - jitter_output_accuracy: 0.9169 - packet_loss_output_accuracy: 0.8677 - val_loss: 1.9044 - val_delay_output_loss: 0.7038 - val_jitter_output_loss: 0.4837 - val_packet_loss_output_loss: 0.6658 - val_delay_output_accuracy: 0.7711 - val_jitter_output_accuracy: 0.8419 - val_packet_loss_output_accuracy: 0.7743
# Epoch 142/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9149 - delay_output_loss: 0.3275 - jitter_output_loss: 0.1993 - packet_loss_output_loss: 0.3365 - delay_output_accuracy: 0.8764 - jitter_output_accuracy: 0.9226 - packet_loss_output_accuracy: 0.8745 - val_loss: 1.9072 - val_delay_output_loss: 0.7001 - val_jitter_output_loss: 0.4728 - val_packet_loss_output_loss: 0.6817 - val_delay_output_accuracy: 0.7645 - val_jitter_output_accuracy: 0.8466 - val_packet_loss_output_accuracy: 0.7629
# Epoch 143/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9288 - delay_output_loss: 0.3355 - jitter_output_loss: 0.1962 - packet_loss_output_loss: 0.3449 - delay_output_accuracy: 0.8738 - jitter_output_accuracy: 0.9237 - packet_loss_output_accuracy: 0.8710 - val_loss: 1.8887 - val_delay_output_loss: 0.6853 - val_jitter_output_loss: 0.4834 - val_packet_loss_output_loss: 0.6687 - val_delay_output_accuracy: 0.7617 - val_jitter_output_accuracy: 0.8344 - val_packet_loss_output_accuracy: 0.7814
# Epoch 144/500
# 716/716 [==============================] - 8s 11ms/step - loss: 0.8587 - delay_output_loss: 0.3041 - jitter_output_loss: 0.1850 - packet_loss_output_loss: 0.3169 - delay_output_accuracy: 0.8854 - jitter_output_accuracy: 0.9294 - packet_loss_output_accuracy: 0.8852 - val_loss: 1.8291 - val_delay_output_loss: 0.6592 - val_jitter_output_loss: 0.4373 - val_packet_loss_output_loss: 0.6800 - val_delay_output_accuracy: 0.7770 - val_jitter_output_accuracy: 0.8506 - val_packet_loss_output_accuracy: 0.7770
# Epoch 145/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8956 - delay_output_loss: 0.3200 - jitter_output_loss: 0.1887 - packet_loss_output_loss: 0.3337 - delay_output_accuracy: 0.8801 - jitter_output_accuracy: 0.9249 - packet_loss_output_accuracy: 0.8784 - val_loss: 1.8640 - val_delay_output_loss: 0.6689 - val_jitter_output_loss: 0.4749 - val_packet_loss_output_loss: 0.6696 - val_delay_output_accuracy: 0.7668 - val_jitter_output_accuracy: 0.8348 - val_packet_loss_output_accuracy: 0.7609
# Epoch 146/500
# 716/716 [==============================] - 8s 11ms/step - loss: 0.8939 - delay_output_loss: 0.3163 - jitter_output_loss: 0.1921 - packet_loss_output_loss: 0.3326 - delay_output_accuracy: 0.8826 - jitter_output_accuracy: 0.9266 - packet_loss_output_accuracy: 0.8753 - val_loss: 1.8734 - val_delay_output_loss: 0.6924 - val_jitter_output_loss: 0.4519 - val_packet_loss_output_loss: 0.6755 - val_delay_output_accuracy: 0.7652 - val_jitter_output_accuracy: 0.8494 - val_packet_loss_output_accuracy: 0.7778
# Epoch 147/500
# 716/716 [==============================] - 8s 11ms/step - loss: 0.8396 - delay_output_loss: 0.2964 - jitter_output_loss: 0.1770 - packet_loss_output_loss: 0.3121 - delay_output_accuracy: 0.8912 - jitter_output_accuracy: 0.9325 - packet_loss_output_accuracy: 0.8864 - val_loss: 1.9115 - val_delay_output_loss: 0.6929 - val_jitter_output_loss: 0.5022 - val_packet_loss_output_loss: 0.6630 - val_delay_output_accuracy: 0.7735 - val_jitter_output_accuracy: 0.8376 - val_packet_loss_output_accuracy: 0.7778
# Epoch 148/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8773 - delay_output_loss: 0.3120 - jitter_output_loss: 0.1829 - packet_loss_output_loss: 0.3295 - delay_output_accuracy: 0.8858 - jitter_output_accuracy: 0.9285 - packet_loss_output_accuracy: 0.8797 - val_loss: 1.9154 - val_delay_output_loss: 0.6993 - val_jitter_output_loss: 0.4843 - val_packet_loss_output_loss: 0.6798 - val_delay_output_accuracy: 0.7609 - val_jitter_output_accuracy: 0.8325 - val_packet_loss_output_accuracy: 0.7782
# Epoch 149/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8826 - delay_output_loss: 0.3191 - jitter_output_loss: 0.1841 - packet_loss_output_loss: 0.3267 - delay_output_accuracy: 0.8802 - jitter_output_accuracy: 0.9292 - packet_loss_output_accuracy: 0.8791 - val_loss: 1.9780 - val_delay_output_loss: 0.7164 - val_jitter_output_loss: 0.5053 - val_packet_loss_output_loss: 0.7029 - val_delay_output_accuracy: 0.7597 - val_jitter_output_accuracy: 0.8321 - val_packet_loss_output_accuracy: 0.7645
# Epoch 150/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8773 - delay_output_loss: 0.3126 - jitter_output_loss: 0.1860 - packet_loss_output_loss: 0.3261 - delay_output_accuracy: 0.8838 - jitter_output_accuracy: 0.9278 - packet_loss_output_accuracy: 0.8794 - val_loss: 1.9021 - val_delay_output_loss: 0.7159 - val_jitter_output_loss: 0.5056 - val_packet_loss_output_loss: 0.6293 - val_delay_output_accuracy: 0.7452 - val_jitter_output_accuracy: 0.8451 - val_packet_loss_output_accuracy: 0.7861
# Epoch 151/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9296 - delay_output_loss: 0.3325 - jitter_output_loss: 0.1968 - packet_loss_output_loss: 0.3492 - delay_output_accuracy: 0.8735 - jitter_output_accuracy: 0.9232 - packet_loss_output_accuracy: 0.8688 - val_loss: 2.0001 - val_delay_output_loss: 0.7391 - val_jitter_output_loss: 0.5406 - val_packet_loss_output_loss: 0.6686 - val_delay_output_accuracy: 0.7515 - val_jitter_output_accuracy: 0.8289 - val_packet_loss_output_accuracy: 0.7766
# Epoch 152/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8901 - delay_output_loss: 0.3200 - jitter_output_loss: 0.1865 - packet_loss_output_loss: 0.3317 - delay_output_accuracy: 0.8811 - jitter_output_accuracy: 0.9283 - packet_loss_output_accuracy: 0.8784 - val_loss: 1.9962 - val_delay_output_loss: 0.7155 - val_jitter_output_loss: 0.5466 - val_packet_loss_output_loss: 0.6827 - val_delay_output_accuracy: 0.7570 - val_jitter_output_accuracy: 0.8293 - val_packet_loss_output_accuracy: 0.7648
# Epoch 153/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9440 - delay_output_loss: 0.3361 - jitter_output_loss: 0.2074 - packet_loss_output_loss: 0.3498 - delay_output_accuracy: 0.8721 - jitter_output_accuracy: 0.9202 - packet_loss_output_accuracy: 0.8710 - val_loss: 1.9368 - val_delay_output_loss: 0.6754 - val_jitter_output_loss: 0.4924 - val_packet_loss_output_loss: 0.7182 - val_delay_output_accuracy: 0.7664 - val_jitter_output_accuracy: 0.8360 - val_packet_loss_output_accuracy: 0.7664
# Epoch 154/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8550 - delay_output_loss: 0.3041 - jitter_output_loss: 0.1795 - packet_loss_output_loss: 0.3191 - delay_output_accuracy: 0.8861 - jitter_output_accuracy: 0.9310 - packet_loss_output_accuracy: 0.8837 - val_loss: 1.9070 - val_delay_output_loss: 0.6993 - val_jitter_output_loss: 0.5176 - val_packet_loss_output_loss: 0.6376 - val_delay_output_accuracy: 0.7676 - val_jitter_output_accuracy: 0.8447 - val_packet_loss_output_accuracy: 0.7877
# Epoch 155/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8630 - delay_output_loss: 0.3016 - jitter_output_loss: 0.1879 - packet_loss_output_loss: 0.3209 - delay_output_accuracy: 0.8870 - jitter_output_accuracy: 0.9266 - packet_loss_output_accuracy: 0.8828 - val_loss: 1.8064 - val_delay_output_loss: 0.6505 - val_jitter_output_loss: 0.4517 - val_packet_loss_output_loss: 0.6524 - val_delay_output_accuracy: 0.7743 - val_jitter_output_accuracy: 0.8403 - val_packet_loss_output_accuracy: 0.7774
# Epoch 156/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8841 - delay_output_loss: 0.3150 - jitter_output_loss: 0.1923 - packet_loss_output_loss: 0.3251 - delay_output_accuracy: 0.8805 - jitter_output_accuracy: 0.9264 - packet_loss_output_accuracy: 0.8804 - val_loss: 1.9068 - val_delay_output_loss: 0.6816 - val_jitter_output_loss: 0.5029 - val_packet_loss_output_loss: 0.6739 - val_delay_output_accuracy: 0.7440 - val_jitter_output_accuracy: 0.8164 - val_packet_loss_output_accuracy: 0.7393
# Epoch 157/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9448 - delay_output_loss: 0.3292 - jitter_output_loss: 0.2086 - packet_loss_output_loss: 0.3572 - delay_output_accuracy: 0.8754 - jitter_output_accuracy: 0.9189 - packet_loss_output_accuracy: 0.8686 - val_loss: 1.8821 - val_delay_output_loss: 0.6816 - val_jitter_output_loss: 0.4901 - val_packet_loss_output_loss: 0.6587 - val_delay_output_accuracy: 0.7794 - val_jitter_output_accuracy: 0.8447 - val_packet_loss_output_accuracy: 0.7790
# Epoch 158/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.9442 - delay_output_loss: 0.3357 - jitter_output_loss: 0.2055 - packet_loss_output_loss: 0.3518 - delay_output_accuracy: 0.8768 - jitter_output_accuracy: 0.9210 - packet_loss_output_accuracy: 0.8709 - val_loss: 1.9026 - val_delay_output_loss: 0.7158 - val_jitter_output_loss: 0.4970 - val_packet_loss_output_loss: 0.6383 - val_delay_output_accuracy: 0.7641 - val_jitter_output_accuracy: 0.8333 - val_packet_loss_output_accuracy: 0.7782
# Epoch 159/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8894 - delay_output_loss: 0.3148 - jitter_output_loss: 0.1915 - packet_loss_output_loss: 0.3312 - delay_output_accuracy: 0.8832 - jitter_output_accuracy: 0.9247 - packet_loss_output_accuracy: 0.8794 - val_loss: 1.8714 - val_delay_output_loss: 0.6790 - val_jitter_output_loss: 0.4638 - val_packet_loss_output_loss: 0.6766 - val_delay_output_accuracy: 0.7609 - val_jitter_output_accuracy: 0.8443 - val_packet_loss_output_accuracy: 0.7818
# Epoch 160/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8629 - delay_output_loss: 0.3045 - jitter_output_loss: 0.1857 - packet_loss_output_loss: 0.3197 - delay_output_accuracy: 0.8866 - jitter_output_accuracy: 0.9303 - packet_loss_output_accuracy: 0.8811 - val_loss: 1.8870 - val_delay_output_loss: 0.6967 - val_jitter_output_loss: 0.4812 - val_packet_loss_output_loss: 0.6574 - val_delay_output_accuracy: 0.7558 - val_jitter_output_accuracy: 0.8356 - val_packet_loss_output_accuracy: 0.7825
# Epoch 161/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8466 - delay_output_loss: 0.2996 - jitter_output_loss: 0.1796 - packet_loss_output_loss: 0.3148 - delay_output_accuracy: 0.8890 - jitter_output_accuracy: 0.9303 - packet_loss_output_accuracy: 0.8857 - val_loss: 1.8940 - val_delay_output_loss: 0.6906 - val_jitter_output_loss: 0.4910 - val_packet_loss_output_loss: 0.6616 - val_delay_output_accuracy: 0.7641 - val_jitter_output_accuracy: 0.8305 - val_packet_loss_output_accuracy: 0.7727
# Epoch 162/500
# 716/716 [==============================] - 8s 11ms/step - loss: 0.8636 - delay_output_loss: 0.3052 - jitter_output_loss: 0.1832 - packet_loss_output_loss: 0.3229 - delay_output_accuracy: 0.8857 - jitter_output_accuracy: 0.9296 - packet_loss_output_accuracy: 0.8825 - val_loss: 1.9291 - val_delay_output_loss: 0.7154 - val_jitter_output_loss: 0.5041 - val_packet_loss_output_loss: 0.6581 - val_delay_output_accuracy: 0.7609 - val_jitter_output_accuracy: 0.8348 - val_packet_loss_output_accuracy: 0.7806
# Epoch 163/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8990 - delay_output_loss: 0.3245 - jitter_output_loss: 0.1908 - packet_loss_output_loss: 0.3327 - delay_output_accuracy: 0.8773 - jitter_output_accuracy: 0.9264 - packet_loss_output_accuracy: 0.8767 - val_loss: 1.9290 - val_delay_output_loss: 0.7195 - val_jitter_output_loss: 0.5161 - val_packet_loss_output_loss: 0.6424 - val_delay_output_accuracy: 0.7755 - val_jitter_output_accuracy: 0.8403 - val_packet_loss_output_accuracy: 0.7920
# Epoch 164/500
# 716/716 [==============================] - 8s 11ms/step - loss: 0.8689 - delay_output_loss: 0.3104 - jitter_output_loss: 0.1869 - packet_loss_output_loss: 0.3203 - delay_output_accuracy: 0.8863 - jitter_output_accuracy: 0.9277 - packet_loss_output_accuracy: 0.8796 - val_loss: 1.9976 - val_delay_output_loss: 0.7266 - val_jitter_output_loss: 0.5123 - val_packet_loss_output_loss: 0.7060 - val_delay_output_accuracy: 0.7550 - val_jitter_output_accuracy: 0.8329 - val_packet_loss_output_accuracy: 0.7759
# Epoch 165/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8492 - delay_output_loss: 0.3004 - jitter_output_loss: 0.1810 - packet_loss_output_loss: 0.3151 - delay_output_accuracy: 0.8862 - jitter_output_accuracy: 0.9311 - packet_loss_output_accuracy: 0.8846 - val_loss: 2.0016 - val_delay_output_loss: 0.7344 - val_jitter_output_loss: 0.4987 - val_packet_loss_output_loss: 0.7162 - val_delay_output_accuracy: 0.7739 - val_jitter_output_accuracy: 0.8392 - val_packet_loss_output_accuracy: 0.7684
# Epoch 166/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8477 - delay_output_loss: 0.2986 - jitter_output_loss: 0.1802 - packet_loss_output_loss: 0.3162 - delay_output_accuracy: 0.8877 - jitter_output_accuracy: 0.9310 - packet_loss_output_accuracy: 0.8851 - val_loss: 1.9877 - val_delay_output_loss: 0.6979 - val_jitter_output_loss: 0.5514 - val_packet_loss_output_loss: 0.6855 - val_delay_output_accuracy: 0.7731 - val_jitter_output_accuracy: 0.8455 - val_packet_loss_output_accuracy: 0.7755
# Epoch 167/500
# 716/716 [==============================] - 7s 10ms/step - loss: 0.8514 - delay_output_loss: 0.3053 - jitter_output_loss: 0.1811 - packet_loss_output_loss: 0.3123 - delay_output_accuracy: 0.8863 - jitter_output_accuracy: 0.9300 - packet_loss_output_accuracy: 0.8856 - val_loss: 1.9544 - val_delay_output_loss: 0.7138 - val_jitter_output_loss: 0.4794 - val_packet_loss_output_loss: 0.7102 - val_delay_output_accuracy: 0.7605 - val_jitter_output_accuracy: 0.8384 - val_packet_loss_output_accuracy: 0.7629

# %%
def plot_history(history):
    plt.figure(figsize=(10, 6))

    # Plot training & validation loss values
    plt.subplot(2, 2, 1)
    plt.plot(history['loss'], label='Training Loss')
    if 'val_loss' in history:
        plt.plot(history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    # Plot training & validation delay_output accuracy values
    plt.subplot(2, 2, 2)
    plt.plot(history['delay_output_accuracy'], label='Training Delay Accuracy')
    if 'val_delay_output_accuracy' in history:
        plt.plot(history['val_delay_output_accuracy'], label='Validation Delay Accuracy')
    plt.title('Delay Output Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot training & validation jitter_output accuracy values
    plt.subplot(2, 2, 3)
    plt.plot(history['jitter_output_accuracy'], label='Training Jitter Accuracy')
    if 'val_jitter_output_accuracy' in history:
        plt.plot(history['val_jitter_output_accuracy'], label='Validation Jitter Accuracy')
    plt.title('Jitter Output Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot training & validation packet_loss_output accuracy values
    plt.subplot(2, 2, 4)
    plt.plot(history['packet_loss_output_accuracy'], label='Training Packet Loss Accuracy')
    if 'val_packet_loss_output_accuracy' in history:
        plt.plot(history['val_packet_loss_output_accuracy'], label='Validation Packet Loss Accuracy')
    plt.title('Packet Loss Output Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    plt.tight_layout()
    plt.show()

def combine_histories(history_list):
    combined_history = {}
    for history in history_list:
        for key, values in history.history.items():
            if key not in combined_history:
                combined_history[key] = values
            else:
                combined_history[key].extend(values)
    return combined_history

def plot_():
  plot_history(combine_histories(history_list))

# %%
plot_()

# %%
# %load_ext tensorboard
# %tensorboard --logdir drive/MyDrive/tensorflow_logs_20240519_144352
